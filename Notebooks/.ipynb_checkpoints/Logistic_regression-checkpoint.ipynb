# %% [markdown]
# # Predicting Loan Payback using Logistic Regression

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("../loan_dataset_20000.csv") 

X_raw = df.drop("loan_paid_back", axis=1)
y = df["loan_paid_back"]

# monthly and yearly income carry the same info monhly = yearly / 12
X_raw = X_raw.drop(columns=['monthly_income'])

# %%
X = X_raw.copy()
y = y.copy()

categorical_cols = X.select_dtypes(include='object').columns.tolist()
numeric_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()



preprocessor_scaled = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ]
)



target_col = "loan_paid_back" 
X = df.drop(columns=[target_col])
y = df[target_col]

# stratify keeps the 0/1 ratio similar in train and test (important for FP/FN work)
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
lr = LogisticRegression(max_iter=1000)

pipeline_lr = Pipeline([
    ('prep', preprocessor_scaled),
    ('model', lr)
])

pipeline_lr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age', 'annual_income',
#                                                    'debt_to_income_ratio',
#                                                    'credit_score',
#                                                    'loan_amount',
#                                                    'interest_rate', 'loan_term',
#                                                    'installment',
#                                                    'num_of_open_accounts',
#                                                    'total_credit_limit',
#                                                    'current_balance',
#                                                    'delinquency_history',
#                                                    'public_records',
#                                                    'num_of_delinquencies']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender', 'marital_status',
#                                                    'education_level',
#                                                    'employment_status',
#                                                    'loan_purpose',
#                                                    'grade_subgrade'])])),
#                 ('model', LogisticRegression(max_iter=1000))])

# %%
y_pred_lr = pipeline_lr.predict(X_test)
y_proba_lr = pipeline_lr.predict_proba(X_test)[:, 1]

# %%
cm = confusion_matrix(y_test, y_pred_lr)

plt.figure(figsize=(5,4))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=['Predicted: Not Paid', 'Predicted: Paid'],
    yticklabels=['Actual: Not Paid', 'Actual: Paid']
)
plt.title('Confusion Matrix – Logistic regression')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67       800
#            1       0.90      0.96      0.93      3200
#
#     accuracy                           0.89      4000
#    macro avg       0.85      0.77      0.80      4000
# weighted avg       0.88      0.89      0.88      4000

# %%
prep = pipeline_lr.named_steps["prep"]
feature_names = prep.get_feature_names_out()


logreg = pipeline_lr.named_steps["model"]


coefs = lr.coef_[0]

features_with_importance = sorted(
    zip(feature_names, coefs),
    key=lambda x: abs(x[1]),
    reverse=True
)

for feature, coef in features_with_importance:
    print(f"{feature} : {coef}")
# Out:
# cat__employment_status_Retired : 3.854181104817815
# cat__employment_status_Unemployed : -3.403978203379132
# cat__employment_status_Student : -1.9673828991238778
# cat__employment_status_Employed : 1.1322956194264158
# cat__employment_status_Self-employed : 1.1075258245470456
# num__credit_score : 0.9918517382787274
# num__debt_to_income_ratio : -0.8245155979884419
# cat__grade_subgrade_F5 : 0.6796651874631061
# cat__grade_subgrade_A2 : 0.6723734451823999
# cat__grade_subgrade_A1 : 0.4649006737338508
# cat__grade_subgrade_A3 : 0.4255156361462343
# cat__grade_subgrade_C3 : -0.40787928979150206
# cat__grade_subgrade_F2 : 0.3819445680432794
# cat__grade_subgrade_B1 : -0.3773146808502092
# cat__grade_subgrade_C4 : -0.372954867161832
# cat__grade_subgrade_B3 : 0.3331846672996112
# cat__loan_purpose_Home : 0.3278535692992977
# cat__grade_subgrade_D4 : -0.32249180621825113
# cat__grade_subgrade_D5 : -0.32232106599913124
# cat__grade_subgrade_C5 : -0.3206533218922462
# cat__grade_subgrade_C2 : -0.31641253919266676
# cat__gender_Male : 0.31289746385802863
# cat__grade_subgrade_D3 : -0.30997648506494657
# cat__grade_subgrade_D2 : -0.3053298695759823
# cat__marital_status_Divorced : 0.29260553576812787
# cat__grade_subgrade_B4 : 0.28940493255090854
# cat__grade_subgrade_F1 : 0.2774081855742148
# cat__grade_subgrade_E1 : 0.27061204391310184
# cat__grade_subgrade_F4 : 0.26731911458501767
# cat__gender_Female : 0.26233433306912557
# cat__grade_subgrade_A4 : -0.2512615558597787
# cat__marital_status_Single : 0.24420516198277534
# cat__grade_subgrade_F3 : 0.2407462273295687
# cat__grade_subgrade_E3 : 0.23502215676546448
# cat__education_level_PhD : 0.2098243464986648
# cat__education_level_High School : 0.20701071890869932
# cat__grade_subgrade_D1 : -0.18579002125465466
# cat__marital_status_Married : 0.1756080349810181
# cat__grade_subgrade_E4 : -0.17427530869031346
# cat__loan_purpose_Other : 0.154375488984171
# cat__gender_Other : 0.14740964936111198
# cat__grade_subgrade_A5 : -0.13535668621190222
# cat__loan_purpose_Business : 0.12734989179831638
# cat__grade_subgrade_E2 : -0.12502278152109575
# cat__loan_purpose_Education : -0.11972239923988999
# cat__education_level_Other : 0.11556780194079913
# cat__education_level_Master's : 0.10737339090295779
# cat__loan_purpose_Debt consolidation : 0.10395283357505922
# cat__grade_subgrade_C1 : -0.08757001989984729
# cat__grade_subgrade_E5 : 0.08736924806346616
# cat__education_level_Bachelor's : 0.082865188037144
# cat__grade_subgrade_B2 : 0.07734742211248431
# cat__loan_purpose_Vacation : 0.07648099766163075
# cat__loan_purpose_Car : 0.07269943743137292
# num__num_of_delinquencies : 0.066877050427638
# num__annual_income : 0.06458712242896099
# num__delinquency_history : -0.05488875096902394
# num__total_credit_limit : -0.04354940091282448
# num__loan_amount : 0.03982420930161699
# cat__grade_subgrade_B5 : 0.03443823670991899
# num__installment : -0.028746900052636516
# cat__loan_purpose_Medical : -0.020348373221685003
# num__age : 0.019462500036771076
# num__interest_rate : -0.01724578465961058
# cat__marital_status_Widowed : 0.010222713556349166
# num__public_records : -0.00869248922617785
# num__loan_term : -0.00725057360517449
# num__current_balance : -0.0057092118821498025
# num__num_of_open_accounts : -1.9091571300697465e-05

# %%
top = features_with_importance[:10]
features, coefs = zip(*top)

plt.figure(figsize=(8, 5))
plt.barh(features, coefs)
plt.xlabel("Logistic Regression Coefficient")
plt.title("Top 10 Feature Importances – Logistic Regression")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
